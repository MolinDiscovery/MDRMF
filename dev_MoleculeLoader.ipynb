# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors

# %%
class MoleculeLoader:
    """
    A class used to load and process molecular data.
    """
    def __init__(self, datafile: str, smi_col: str, scores_col: str) -> None:
        """
        Initializes the MoleculeLoader with a data file.

        Args:
            - datafile (str): The name of the data file to load.
            - smi_col (str): The name of the column containing SMILES strings in the `DataFrame`.
            - scores_col(str): The name of the column containing the docking scores in the `DataFrame`.
        """
        self.datafile = datafile
        self.smi_col = smi_col
        self.scores_col = scores_col
        self._df = None

    def _load_data(self) -> pd.DataFrame:
        """
        Loads data from the data file into a DataFrame.

        This method is called automatically when accessing the `df` property
        if the data has not been loaded yet.

        Returns:
            - pd.DataFrame: The loaded data.
        """
        self._df = pd.read_csv(self.datafile)

    def _process_data(self):
        """
        Processes the loaded DataFrame.

        If the 'molecule' column does not exist in the DataFrame,
        it is created by applying the `Chem.MolFromSmiles` function
        to the 'SMILES' column.
        """
        if 'molecules' not in self._df.columns:
            self._df['molecules'] = self._df[self.smi_col].apply(Chem.MolFromSmiles)

        self._df['scores'] = self._df[self.scores_col]
        self._df.drop(columns=[self.scores_col], inplace=True)

    @property
    def df(self):
        """
        Provides access to the loaded and processed DataFrame.

        If the data has not been loaded yet, it is loaded automatically
        the first time this property is accessed.

        Returns:
            - pd.DataFrame: The loaded DataFrame.
        """
        if self._df is None:
            self._load_data()
            self._process_data()
        return self._df

    def filter_by_mol_wt(self, MolWt: int):
        if self._df is None:
            raise ValueError("DataFrame is not loaded. Please load the data using .df on your object.")

        self._df = self._df[self._df['molecules'].apply(Descriptors.MolWt) < MolWt]

        return self

    def filter_by_num_atoms(self, max_atoms: int):
        if self._df is None:
            raise ValueError("DataFrame is not loaded. Please load the data using .df on your object.")
        
        self._df = self._df[self._df['molecules'].apply(lambda mol: mol.GetNumAtoms()) <= max_atoms]

        return self

# %%
loader = MoleculeLoader("10K.csv", 'SMILES', 'r_i_docking_score')

# %%
loader.df
# Out:
#       Unnamed: 0  i_i_glide_lignum  \
# 0              0             13477
# 1              1               516
# 2              2              9425
# 3              3             14512
# 4              4              9615
# ...          ...               ...
# 9893        9893              2451
# 9894        9894              7813
# 9895        9895             11442
# 9896        9896             13971
# 9897        9897             11630
#
#                                                  SMILES  \
# 0     C[C@@H](NC(=O)N1C[C@H](c2ccccc2)[C@H]2COCC[C@H...
# 1     O=C(Nc1cccc(C(=O)N2CCC(c3c[nH]c4ncccc34)CC2)c1...
# 2     Cc1nn(-c2ccccc2)c2nc(C(=O)N3CCC([C@H]4C(=O)Nc5...
# 3     Cc1cc(C)cc(C(=O)N2CCC[C@H](C(=O)NCc3cccc([C@@]...
# 4     CS(=O)(=O)c1ccc(F)c(C(=O)Nc2ccc(-c3nc(-c4ccccc...
# ...                                                 ...
# 9893                                  O=C([O-])C(F)(F)F
# 9894   Cc1cnn(C)c1S(=O)(=O)NC[C@@H](Cc1ccccn1)C(=O)[O-]
# 9895        Cn1cccc(C(=O)N2CCN(C3CC3)c3ccc(Cl)cc32)c1=O
# 9896    O=C([O-])[C@H]1CC[C@@H](C(=O)N2CCCc3ccccc32)CC1
# 9897                        CCNS(=O)(=O)c1cc(NCCOC)ccn1
#
#                                               molecules     scores
# 0     <rdkit.Chem.rdchem.Mol object at 0x00000250BA6... -13.126800
# 1     <rdkit.Chem.rdchem.Mol object at 0x00000250BA6... -12.662900
# 2     <rdkit.Chem.rdchem.Mol object at 0x00000250BA6... -12.487000
# 3     <rdkit.Chem.rdchem.Mol object at 0x00000250BA6... -12.483500
# 4     <rdkit.Chem.rdchem.Mol object at 0x00000250BA6... -12.478500
# ...                                                 ...        ...
# 9893  <rdkit.Chem.rdchem.Mol object at 0x00000250C54...  -0.560302
# 9894  <rdkit.Chem.rdchem.Mol object at 0x00000250C54...  -0.384887
# 9895  <rdkit.Chem.rdchem.Mol object at 0x00000250C54...  -0.269109
# 9896  <rdkit.Chem.rdchem.Mol object at 0x00000250C54...  -0.150473
# 9897  <rdkit.Chem.rdchem.Mol object at 0x00000250C54...  -0.145596
#
# [9898 rows x 5 columns]

# %%
loader.filter_by_mol_wt(300)

# %%
loader.filter_by_num_atoms(15)

# %%
loader.df
# Out:
#       Unnamed: 0  i_i_glide_lignum                                    SMILES  \
# 7134        7134              8866                     Cc1nc(NC(CO)CO)ccc1Br
# 7162        7162             11230              [NH3+]CCc1c[nH]c2cc(Br)ccc12
# 7764        7764              6645              Brc1c[nH]c(-c2nnc3n2CCCC3)c1
# 7927        7927              1044             Cn1c(CO)nnc1[C@H]1CCC[NH2+]C1
# 7968        7968              8297               CNC(=O)c1n[nH]c2ccc(Br)cc12
# 8009        8009             18990          [NH3+][C@@H]1CCCN(C(=O)C2CCC2)C1
# 8029        8029              1043            Cn1c(CO)nnc1[C@@H]1CCC[NH2+]C1
# 8407        8407             18837                Cn1cnc2c1CC[NH2+]C21CCOCC1
# 8428        8428              3079        CC(C)([NH3+])c1nc(-c2ccc(Br)o2)no1
# 8566        8566             19574            C[C@@H]1C(=O)NCCN1c1ccc(Br)cn1
# 8706        8706              7671          CC(C)c1nnc2n1C[C@@H](C[NH3+])CC2
# 8810        8810              6349  COC(=O)[C@H](NC(=O)[C@H](C)C[NH3+])C(C)C
# 8829        8829              4139                CC(C)(CO)NC(=O)c1ccc(Br)o1
# 8836        8836              5636                  CC(C)NC(=O)c1cc(N)ncc1Br
# 8862        8862              6237     Cc1nc([C@@H]2CCC[NH2+]C2)sc1C(=O)[O-]
# 9023        9023              8167                  O=C1CN(c2cncc(Br)c2)CCN1
# 9123        9123             17694   CC[C@@H](NC(=O)[C@H]1CCC[NH2+]1)C(=O)OC
# 9276        9276             13345         O[C@H]1CC[C@@H](Nc2ccc(Br)cn2)CC1
# 9305        9305              5132      COC(=O)[C@H]1C[NH2+]C[C@@H]1c1cncn1C
# 9310        9310              4140            [NH3+]C1CN(c2nc3ccccc3[nH]2)C1
# 9387        9387              9187          O=C([O-])c1csc(CC2CC[NH2+]CC2)n1
# 9404        9404             17692  CC[C@@H](NC(=O)[C@@H]1CCC[NH2+]1)C(=O)OC
# 9434        9434              9251            CC[C@@H](C)NC(=O)C1CC[NH2+]CC1
# 9452        9452             14401          COC(=O)c1cnc(C2CC[NH2+]CC2)[nH]1
# 9515        9515             13692      CC1=[NH+][C@H](C)C(=O)Nc2cc(Br)ccc21
# 9623        9623             20501                  [NH3+]Cc1nnc(N2CCCCC2)o1
# 9663        9663             16965     C[N@@H+]1CCC[C@@H](N2CC[NH2+]CC2=O)C1
# 9689        9689              4817            COC(=O)C(C)(C)CNC(=O)CCC[NH3+]
# 9690        9690              5700             Cc1n[nH]c(C(=O)N2CC(C)C2)c1Br
# 9733        9733             17129            O=S(=O)(c1cccs1)N1CCC[NH2+]CC1
# 9749        9749             19573                  Cc1nccc(N2CC[NH2+]CC2)n1
# 9799        9799              8168         Cc1ncc(S(=O)(=O)N(C)CC(=O)[O-])s1
# 9844        9844              8867               O=C(c1ccc(Br)cn1)N1CC(CO)C1
# 9877        9877              8714         Cn1cc(S(=O)(=O)N2CC([NH3+])C2)cn1
# 9893        9893              2451                         O=C([O-])C(F)(F)F
#
#                                               molecules    scores
# 7134  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -7.023470
# 7162  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -7.010870
# 7764  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -6.655240
# 7927  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -6.527260
# 7968  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -6.498830
# 8009  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -6.476300
# 8029  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -6.458890
# 8407  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -6.194130
# 8428  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -6.175670
# 8566  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -6.057450
# 8706  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -5.923550
# 8810  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -5.821710
# 8829  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -5.807050
# 8836  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -5.794940
# 8862  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -5.763430
# 9023  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -5.594310
# 9123  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -5.465900
# 9276  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -5.228580
# 9305  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -5.190940
# 9310  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -5.185370
# 9387  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -5.024440
# 9404  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -4.981340
# 9434  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -4.925550
# 9452  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -4.873290
# 9515  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -4.695140
# 9623  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -4.382350
# 9663  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -4.214230
# 9689  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -4.099010
# 9690  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -4.098920
# 9733  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -3.863830
# 9749  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -3.767030
# 9799  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -3.352020
# 9844  <rdkit.Chem.rdchem.Mol object at 0x00000250BA5... -2.790520
# 9877  <rdkit.Chem.rdchem.Mol object at 0x00000250C54... -2.049620
# 9893  <rdkit.Chem.rdchem.Mol object at 0x00000250C54... -0.560302

# %%
loader2 = MoleculeLoader("10K.csv", 'SMILES', 'r_i_docking_score')

# %%
loader2.df
# Out:
#       Unnamed: 0  i_i_glide_lignum  \
# 0              0             13477
# 1              1               516
# 2              2              9425
# 3              3             14512
# 4              4              9615
# ...          ...               ...
# 9893        9893              2451
# 9894        9894              7813
# 9895        9895             11442
# 9896        9896             13971
# 9897        9897             11630
#
#                                                  SMILES  \
# 0     C[C@@H](NC(=O)N1C[C@H](c2ccccc2)[C@H]2COCC[C@H...
# 1     O=C(Nc1cccc(C(=O)N2CCC(c3c[nH]c4ncccc34)CC2)c1...
# 2     Cc1nn(-c2ccccc2)c2nc(C(=O)N3CCC([C@H]4C(=O)Nc5...
# 3     Cc1cc(C)cc(C(=O)N2CCC[C@H](C(=O)NCc3cccc([C@@]...
# 4     CS(=O)(=O)c1ccc(F)c(C(=O)Nc2ccc(-c3nc(-c4ccccc...
# ...                                                 ...
# 9893                                  O=C([O-])C(F)(F)F
# 9894   Cc1cnn(C)c1S(=O)(=O)NC[C@@H](Cc1ccccn1)C(=O)[O-]
# 9895        Cn1cccc(C(=O)N2CCN(C3CC3)c3ccc(Cl)cc32)c1=O
# 9896    O=C([O-])[C@H]1CC[C@@H](C(=O)N2CCCc3ccccc32)CC1
# 9897                        CCNS(=O)(=O)c1cc(NCCOC)ccn1
#
#                                               molecules     scores
# 0     <rdkit.Chem.rdchem.Mol object at 0x00000250C56... -13.126800
# 1     <rdkit.Chem.rdchem.Mol object at 0x00000250C56... -12.662900
# 2     <rdkit.Chem.rdchem.Mol object at 0x00000250C56... -12.487000
# 3     <rdkit.Chem.rdchem.Mol object at 0x00000250C56... -12.483500
# 4     <rdkit.Chem.rdchem.Mol object at 0x00000250C56... -12.478500
# ...                                                 ...        ...
# 9893  <rdkit.Chem.rdchem.Mol object at 0x00000250C55...  -0.560302
# 9894  <rdkit.Chem.rdchem.Mol object at 0x00000250C55...  -0.384887
# 9895  <rdkit.Chem.rdchem.Mol object at 0x00000250C55...  -0.269109
# 9896  <rdkit.Chem.rdchem.Mol object at 0x00000250C55...  -0.150473
# 9897  <rdkit.Chem.rdchem.Mol object at 0x00000250C55...  -0.145596
#
# [9898 rows x 5 columns]

# %%
loader2.filter_by_num_atoms(17).filter_by_mol_wt(300)

# %%
loader2.df
# Out:
#       Unnamed: 0  i_i_glide_lignum  \
# 3888        3888              2813
# 3974        3974              9256
# 4543        4543              9255
# 4678        4678              4358
# 5182        5182              1584
# ...          ...               ...
# 9865        9865             11634
# 9877        9877              8714
# 9889        9889              5148
# 9893        9893              2451
# 9897        9897             11630
#
#                                               SMILES  \
# 3888  O=C(NS(=O)(=O)[C@@H]1CCOC1)[C@H]1C[C@@H]1C1CC1
# 3974                O=S(=O)(C[C@@H]1CCCO1)Nc1ccccc1O
# 4543                 O=C(c1ccc(Cl)cc1)N1CCCC[C@H]1CO
# 4678                   CC(C)(C)c1nsc(NCC2(O)CCCC2)n1
# 5182           [NH3+]Cc1ccc(-c2cccc(C(=O)[O-])c2)cc1
# ...                                              ...
# 9865           CN(C(C)(C)C(=O)[O-])S(=O)(=O)c1ccnn1C
# 9877               Cn1cc(S(=O)(=O)N2CC([NH3+])C2)cn1
# 9889              C[NH+]1CCN(c2cnc(C(=O)[O-])cn2)CC1
# 9893                               O=C([O-])C(F)(F)F
# 9897                     CCNS(=O)(=O)c1cc(NCCOC)ccn1
#
#                                               molecules    scores
# 3888  <rdkit.Chem.rdchem.Mol object at 0x00000250C55... -8.358960
# 3974  <rdkit.Chem.rdchem.Mol object at 0x00000250C55... -8.329660
# 4543  <rdkit.Chem.rdchem.Mol object at 0x00000250C55... -8.122710
# 4678  <rdkit.Chem.rdchem.Mol object at 0x00000250C55... -8.072930
# 5182  <rdkit.Chem.rdchem.Mol object at 0x00000250C55... -7.886170
# ...                                                 ...       ...
# 9865  <rdkit.Chem.rdchem.Mol object at 0x00000250C55... -2.339150
# 9877  <rdkit.Chem.rdchem.Mol object at 0x00000250C55... -2.049620
# 9889  <rdkit.Chem.rdchem.Mol object at 0x00000250C55... -1.058180
# 9893  <rdkit.Chem.rdchem.Mol object at 0x00000250C55... -0.560302
# 9897  <rdkit.Chem.rdchem.Mol object at 0x00000250C55... -0.145596
#
# [192 rows x 5 columns]
